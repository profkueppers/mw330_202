# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Part 1 - Join using the index

# %%
df_orders = pd.read_csv('orders.csv',                 
                 infer_datetime_format=True,
                 parse_dates=['order_date_order'],
                 index_col="order_id"
                 )
df_orders.head()
# Out:
#          order_date_order  customer_id     order_status
# order_id
# 1              2013-07-25        11599           CLOSED
# 2              2013-07-25          256  PENDING_PAYMENT
# 3              2013-07-25        12111         COMPLETE
# 4              2013-07-25         8827           CLOSED
# 5              2013-07-25        11318         COMPLETE

# %%
df_orders.dtypes
# Out:
# order_date_order    datetime64[ns]
# customer_id                  int64
# order_status                object
# dtype: object

# %%
df_orderitems = pd.read_csv('order_items.csv',                 
                 infer_datetime_format=True,
                 index_col=["order_id", "order_item_id"]
                 )
df_orderitems.head()
# Out:
#                         product_id  quantity  subtotal  product_price
# order_id order_item_id
# 1        1                       1    299.98    299.98            957
# 2        2                       1    199.99    199.99           1073
#          3                       5    250.00     50.00            502
#          4                       1    129.99    129.99            403
# 4        5                       2     49.98     24.99            897

# %%
df_orderitems.dtypes
# Out:
# product_id         int64
# quantity         float64
# subtotal         float64
# product_price      int64
# dtype: object

# %%
# join both dataframes
df = pd.merge(df_orders, df_orderitems, left_index=True, right_index=True)
df.head()
# Out:
#                        order_date_order  customer_id     order_status  \
# order_id order_item_id
# 1        1                   2013-07-25        11599           CLOSED
# 2        2                   2013-07-25          256  PENDING_PAYMENT
#          3                   2013-07-25          256  PENDING_PAYMENT
#          4                   2013-07-25          256  PENDING_PAYMENT
# 4        5                   2013-07-25         8827           CLOSED
#
#                         product_id  quantity  subtotal  product_price
# order_id order_item_id
# 1        1                       1    299.98    299.98            957
# 2        2                       1    199.99    199.99           1073
#          3                       5    250.00     50.00            502
#          4                       1    129.99    129.99            403
# 4        5                       2     49.98     24.99            897

# %%
df.to_csv("merged_orders.csv")

# %% [markdown]
# # Part 2 - Joining without index

# %%
df_orders.reset_index(inplace=True)
df_orderitems.reset_index(inplace=True)

# %%
df_orders.head()
# Out:
#    order_id order_date_order  customer_id     order_status
# 0         1       2013-07-25        11599           CLOSED
# 1         2       2013-07-25          256  PENDING_PAYMENT
# 2         3       2013-07-25        12111         COMPLETE
# 3         4       2013-07-25         8827           CLOSED
# 4         5       2013-07-25        11318         COMPLETE

# %%
df_orderitems.head()
# Out:
#    order_id  order_item_id  product_id  quantity  subtotal  product_price
# 0         1              1           1    299.98    299.98            957
# 1         2              2           1    199.99    199.99           1073
# 2         2              3           5    250.00     50.00            502
# 3         2              4           1    129.99    129.99            403
# 4         4              5           2     49.98     24.99            897

# %%
df2 = pd.merge(df_orders, df_orderitems)

# %%
df2.head()
# Out:
#    order_id order_date_order  customer_id     order_status  order_item_id  \
# 0         1       2013-07-25        11599           CLOSED              1
# 1         2       2013-07-25          256  PENDING_PAYMENT              2
# 2         2       2013-07-25          256  PENDING_PAYMENT              3
# 3         2       2013-07-25          256  PENDING_PAYMENT              4
# 4         4       2013-07-25         8827           CLOSED              5
#
#    product_id  quantity  subtotal  product_price
# 0           1    299.98    299.98            957
# 1           1    199.99    199.99           1073
# 2           5    250.00     50.00            502
# 3           1    129.99    129.99            403
# 4           2     49.98     24.99            897

# %%
df2.set_index(['order_id', 'order_item_id'], inplace=True)
df2.head()
# Out:
#                        order_date_order  customer_id     order_status  \
# order_id order_item_id
# 1        1                   2013-07-25        11599           CLOSED
# 2        2                   2013-07-25          256  PENDING_PAYMENT
#          3                   2013-07-25          256  PENDING_PAYMENT
#          4                   2013-07-25          256  PENDING_PAYMENT
# 4        5                   2013-07-25         8827           CLOSED
#
#                         product_id  quantity  subtotal  product_price
# order_id order_item_id
# 1        1                       1    299.98    299.98            957
# 2        2                       1    199.99    199.99           1073
#          3                       5    250.00     50.00            502
#          4                       1    129.99    129.99            403
# 4        5                       2     49.98     24.99            897
