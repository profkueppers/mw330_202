# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN, KMeans

# %% [markdown]
# # EDA: Citibike Trips

# %%
trips = pd.read_parquet("201707-citibike-tripdata.parquet")
trips.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.000000e+05     100000.000000           100000.000000
# mean   1.443573e+03       1464.267370               40.735498
# std    1.982778e+04       1372.691175                0.030510
# min    6.100000e+01         72.000000               40.661063
# 25%    4.160000e+02        365.000000               40.715338
# 50%    7.640000e+02        497.000000               40.734546
# 75%    1.351000e+03       3159.000000               40.759291
# max    2.477222e+06       3474.000000               40.804213
#
#        start station longitude  end station id  end station latitude  \
# count            100000.000000    100000.00000         100000.000000
# mean                -73.984099      1454.93331             40.734973
# std                   0.018102      1369.97110              0.030265
# min                 -74.017134        72.00000             40.655949
# 25%                 -73.997236       363.00000             40.714979
# 50%                 -73.986580       496.00000             40.734546
# 75%                 -73.973715      3158.00000             40.757570
# max                 -73.929891      3474.00000             40.804213
#
#        end station longitude         bikeid    birth year         gender
# count          100000.000000  100000.000000  75319.000000  100000.000000
# mean              -73.984630   22853.967960   1979.319375       0.973700
# std                 0.018087    4971.652132     11.831651       0.687919
# min               -74.017134   14529.000000   1885.000000       0.000000
# 25%               -73.997901   18127.000000   1971.000000       0.000000
# 50%               -73.987030   24922.000000   1982.000000       1.000000
# 75%               -73.973747   27626.000000   1988.000000       1.000000
# max               -73.929891   29832.000000   2001.000000       2.000000

# %%
sns.scatterplot(data=trips, x='start station latitude', y='start station longitude'); plt.show()

# %% [markdown]
# # DBSCAN (I)

# %%
X = trips[['start station latitude', 'start station longitude']]
est = DBSCAN(eps=0.004, min_samples=3, metric="euclidean").fit(X)
labels = est.labels_

# %%
sns.scatterplot(x=X['start station latitude'], y=X['start station longitude'], hue=labels);plt.show()

# %% [markdown]
# # DBSCAN (II)

# %%
X = trips[['start station latitude', 'start station longitude']]

est = DBSCAN(eps=0.007, min_samples=3, metric="euclidean").fit(X)
labels = est.labels_

# %%
sns.scatterplot(x=X['start station latitude'], y=X['start station longitude'], hue=labels); plt.show()

# %% [markdown]
# # K-Means is not working in this case

# %%
est = KMeans(3).fit(X)
sns.scatterplot(x=X['start station latitude'], y=X['start station longitude'], hue=est.labels_); plt.show()

# %%
# for further details see: https://chih-ling-hsu.github.io/2018/01/02/clustering-python

# %% [markdown]
# # MPG case

# %%
df = sns.load_dataset('mpg')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
X = df.iloc[:, :7]
X.dropna(inplace=True)
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X))

# %%
est = KMeans(3).fit(X)
df_viz = df.dropna().copy()
df_viz['cluster'] = est.labels_

# %%
sns.pairplot(data=df_viz, hue='cluster')
# Out:
# C:\Users\kupe0003\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
